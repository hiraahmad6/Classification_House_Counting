# %%
##################################   load one sample image at one time and draw annotations of that  #######################################

##### Low training images are 1581 in the folder TRAIN_DATA/ZEROS , same number of annotations in low_train_dir   ######
##### Low testing images are 357 in the folder TEST_DATA/ZEROS , same number of annotations in low_test_dir   ######
##### Mid training images are 2204 in the folder TRAIN_DATA/ONES , same number of annotations in mid_train_dir   ######
##### Mid testing images are 119 in the folder TEST_DATA/ONES , same number of annotations in mid_test_dir   ######
##### High training images are 852 in the folder TRAIN_DATA/TWOS , same number of annotations in high_train_dir   ######
##### High testing images are 52 in the folder TEST_DATA/TWOS , same number of annotations in high_test_dir   ######

import matplotlib.pyplot as plt
import scipy.io as sio
import imageio
house = imageio.imread('TRAIN_DATA/ZEROS/IMG_8.tiff')

#house = imageio.imread('TEST_DATA/ZEROS/IMG_8.tiff')
#house = imageio.imread('TRAIN_DATA/ONES/IMG_8.tiff')
#house = imageio.imread('TEST_DATA/ONES/IMG_8.tiff')
#house = imageio.imread('TRAIN_DATA/TWOS/IMG_8.tiff')
#house = imageio.imread('TEST_DATA/TWOS/IMG_8.tiff')

annotations = sio.loadmat('low_train_dir/GT_IMG_8.mat')

#annotations = sio.loadmat('low_test_dir/GT_IMG_8.mat')
#annotations = sio.loadmat('mid_train_dir/GT_IMG_8.mat')
#annotations = sio.loadmat('mid_test_dir/GT_IMG_8.mat')
#annotations = sio.loadmat('high_train_dir/GT_IMG_8.mat')
#annotations = sio.loadmat('high_test_dir/GT_IMG_8.mat')



annotations = annotations['annPoints']
plt.imshow(house)
#if(annotations[:,0] and annotations[:,1]):
plt.plot(annotations[:,0],annotations[:,1], 'ro')
# Out:
# /usr/local/lib/python3.6/dist-packages/imageio/plugins/_tifffile.py:7285: UserWarning: module 'imageio.plugins._tifffile' has no attribute 'decode_packbits'
#   Functionality might be degraded or be slow.
#
#   warnings.warn("%s%s" % (e, warn))
# /usr/local/lib/python3.6/dist-packages/imageio/plugins/_tifffile.py:7285: UserWarning: module 'imageio.plugins._tifffile' has no attribute 'decode_lzw'
#   Functionality might be degraded or be slow.
#
#   warnings.warn("%s%s" % (e, warn))
# /usr/local/lib/python3.6/dist-packages/imageio/plugins/_tifffile.py:7285: UserWarning: module 'imageio.plugins._tifffile' has no attribute 'unpack_ints'
#   Functionality might be degraded or be slow.
#
#   warnings.warn("%s%s" % (e, warn))
# /usr/local/lib/python3.6/dist-packages/imageio/plugins/_tifffile.py:7285: UserWarning: module 'imageio.plugins._tifffile' has no attribute 'reverse_bitorder'
#   Functionality might be degraded or be slow.
#
#   warnings.warn("%s%s" % (e, warn))
